# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
directory = 'data/'
os.listdir(directory)
# Out:
# ['Africa Food Production (2004 - 2013).csv',
#  'Africa Food Supply (2004 - 2013).csv']

# %%
df = pd.read_csv(directory+'Africa Food Production (2004 - 2013).csv')
df.head()
# Out:
#    Country                Item  Year  Value
# 0  Algeria  Wheat and products  2004   2731
# 1  Algeria  Wheat and products  2005   2415
# 2  Algeria  Wheat and products  2006   2688
# 3  Algeria  Wheat and products  2007   2319
# 4  Algeria  Wheat and products  2008   1111

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23110 entries, 0 to 23109
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Country  23110 non-null  object
#  1   Item     23110 non-null  object
#  2   Year     23110 non-null  int64
#  3   Value    23110 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 722.3+ KB

# %%
df['Year'].unique()
# Out:
# array([2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013])

# %%
df.isnull().sum()
# Out:
# Country    0
# Item       0
# Year       0
# Value      0
# dtype: int64

# %%
status_df = df.groupby(['Country', 'Year'])['Value'].sum().reset_index()
status_df.head(20)
# Out:
#     Country  Year  Value
# 0   Algeria  2004  15536
# 1   Algeria  2005  15667
# 2   Algeria  2006  16417
# 3   Algeria  2007  14763
# 4   Algeria  2008  13841
# 5   Algeria  2009  19820
# 6   Algeria  2010  20263
# 7   Algeria  2011  21778
# 8   Algeria  2012  24206
# 9   Algeria  2013  26359
# 10   Angola  2004  13028
# 11   Angola  2005  13811
# 12   Angola  2006  14264
# 13   Angola  2007  16025
# 14   Angola  2008  17288
# 15   Angola  2009  22244
# 16   Angola  2010  23805
# 17   Angola  2011  25672
# 18   Angola  2012  20505
# 19   Angola  2013  28857

# %%
import plotly.express as px

# %%
# pip install -U kaleido
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
fig = px.bar(status_df, x='Year', y='Value',
              color='Year',
             labels={'Year'}, height=400)
fig.show()
# Out:
# <div>                            <div id="d9dfc099-2310-46df-89a2-c3e044e79ea7" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9dfc099-2310-46df-89a2-c3e044e79ea7")) {                    Plotly.newPlot(                        "d9dfc099-2310-46df-89a2-c3e044e79ea7",                        [{"alignmentgroup":"True","hovertemplate":"Year=%{marker.color}<br>Value=%{y}<extra></extra>","legendgroup":"","marker":{"color":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,2008,2009,2010,201
# ...

# %%
fig = px.bar(status_df, x='Country', y='Value',
              color='Year',
             labels={'Year'}, height=400)
fig.show()
# Out:
# <div>                            <div id="2b0fccd0-bcc4-4197-a6ec-d088c311f769" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b0fccd0-bcc4-4197-a6ec-d088c311f769")) {                    Plotly.newPlot(                        "2b0fccd0-bcc4-4197-a6ec-d088c311f769",                        [{"alignmentgroup":"True","hovertemplate":"Country=%{x}<br>Value=%{y}<br>Year=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2004,2005,2006,2007,20
# ...

# %%
pip install geopandas
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='pypi.org', port=443): Read timed out. (read timeout=15)")': /simple/geopandas/
# ...
#   Using cached geopandas-0.12.2-py3-none-any.whl (1.1 MB)
# ...
#      |████████████████████████████████| 7.7 MB 168 kB/s eta 0:00:01     |███████▍                        | 1.8 MB 21 kB/s eta 0:04:37     |███████████▉                    | 2.9 MB 37 kB/s eta 0:02:11     |████████████▉                   | 3.1 MB 57 kB/s eta 0:01:22
# ...
#      |████████████████████████████████| 2.3 MB 10 kB/s eta 0:00:0180
# ...
#      |████████████████████████████████| 16.6 MB 176 kB/s eta 0:00:01
# ...
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# ...
#   Using cached munch-2.5.0-py2.py3-none-any.whl (10 kB)
# ...
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd
world_data = gpd.read_file(r'africa.shp')
# Out:
# ---------------------------------------------------------------------------
# CPLE_OpenFailedError                      Traceback (most recent call last)
# File fiona/_shim.pyx:83, in fiona._shim.gdal_open_vector()
#
# File fiona/_err.pyx:291, in fiona._err.exc_wrap_pointer()
#
# CPLE_OpenFailedError: africa.shp: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# DriverError                               Traceback (most recent call last)
# Input In [15], in <cell line: 2>()
#       1 import geopandas as gpd
# ----> 2 world_data = gpd.read_file(r'africa.shp')
#
# File ~/anaconda3/lib/python3.9/site-packages/geopandas/io/file.py:259, in _read_file(filename, bbox, mask, rows, engine, **kwargs)
#     256     path_or_bytes = filename
#     258 if engine == "fiona":
# --> 259     return _read_file_fiona(
#     260         path_or_bytes, from_bytes, bbox=bbox, mask=mask, rows=rows, **kwargs
#     261     )
# ...
